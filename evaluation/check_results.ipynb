# %%
import json
result_path = "/u/bli16/workspace/sea/evaluation/results/zeroshot/Qwen_Qwen3-8B_199.json"
with open(result_path, "r", encoding="utf-8") as f:
    results = json.load(f)

# %%
all_accuracies = []
for result in results:
    all_accuracies.append(int(result["accuracy"]))
print(sum(all_accuracies) / len(all_accuracies))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 all_accuracies = []
#       2 for result in results:
# ----> 3     all_accuracies.append(int(result["accuracy"]))
#       4 print(sum(all_accuracies) / len(all_accuracies))
#
# TypeError: string indices must be integers, not 'str'
